# %%
import glob
from os.path import join, exists, getsize
from isatools import isatab
from sys import getsizeof
import logging
from collections import deque
import pandas as pd
import numpy as np

def total_size(o, handlers={}, verbose=False):
    """ Returns the approximate memory footprint an object and all of its contents.

    Automatically finds the contents of the following builtin containers and
    their subclasses:  tuple, list, deque, dict, set and frozenset.
    To search other containers, add handlers to iterate over their contents:

        handlers = {SomeContainerClass: iter,
                    OtherContainerClass: OtherContainerClass.get_elements}

    """
    logger = logging.getLogger(__name__)
    all_handlers = {
        tuple: iter,
        list: iter,
        deque: iter,
        dict: lambda d: chain.from_iterable(d.items()),
        set: iter,
        frozenset: iter,
    }
    all_handlers.update(handlers)
    seen = set()
    default_size = getsizeof(0)

    def sizeof(o):
        if id(o) in seen:       # do not double count the same object
            return 0
        seen.add(id(o))
        s = getsizeof(o, default_size)

        if verbose:
            logger.info(s, type(o), repr(o), file=stderr)

        for typ, handler in all_handlers.items():
            if isinstance(o, typ):
                s += sum(map(sizeof, handler(o)))
                break
        return s

    return sizeof(o)

# %%
isa_synthetic_dir = "/Users/davidjohnson/Development/isa_memory_study3/data/synthetic/"
isa_synthetic_list = [isatab.load(i) for i in glob.iglob(isa_synthetic_dir + "*")]

# %%
print("fname,disk_size,df_size,isa_size,study_id")
for isa_synthetic in isa_synthetic_list:
    study_id = isa_synthetic.identifier
    for study in isa_synthetic.studies:
        fname = study.filename
        study_file_path = join(isa_synthetic_dir, isa_synthetic.identifier, study.filename)
        disk_size = getsize(study_file_path)
        isa_size = total_size(study.process_sequence)
        df_size = total_size(pd.read_csv(study_file_path))
        print("{},{},{},{},{}".format(fname, disk_size, df_size, isa_size, study_id))
        for assay in study.assays:
            fname = assay.filename
            assay_file_path = join(isa_synthetic_dir, isa_synthetic.identifier, assay.filename)
            disk_size = getsize(assay_file_path)
            isa_size = total_size(assay.process_sequence)
            df_size = total_size(pd.read_csv(assay_file_path))
            print("{},{},{},{},{}".format(fname, disk_size, df_size, isa_size, study_id))
# Out:
# fname,disk_size,df_size,isa_size,study_id
# study.txt,8976,11075,2712,synthetic-isa-1sample-6assays
# a_blood_ms_FIA_positive_assay.txt,14646,16704,5312,synthetic-isa-1sample-6assays
# a_blood_ms_FIA_negative_assay.txt,14486,16544,5312,synthetic-isa-1sample-6assays
# a_blood_ms_LC_positive_assay.txt,18561,21974,5312,synthetic-isa-1sample-6assays
# a_blood_ms_LC_negative_assay.txt,18561,21974,5312,synthetic-isa-1sample-6assays
# a_blood_ms_GC_positive_assay.txt,18561,21974,5312,synthetic-isa-1sample-6assays
# a_blood_ms_GC_negative_assay.txt,18561,21974,5312,synthetic-isa-1sample-6assays
# study.txt,26597,33176,7912,synthetic-isa-3samples-1assay
# a_sweat_ms_GC_negative_assay.txt,18841,22254,5312,synthetic-isa-3samples-1assay
# a_blood_ms_GC_negative_assay.txt,18801,22214,5312,synthetic-isa-3samples-1assay
# a_tears_ms_GC_negative_assay.txt,18841,22254,5312,synthetic-isa-3samples-1assay
# study.txt,11974,13675,2712,synthetic-isa-1sample-1assay
# a_blood_ms_GC_negative_assay.txt,21770,24814,5312,synthetic-isa-1sample-1assay
# study.txt,26477,33056,7912,synthetic-isa-3samples-6assays
# a_blood_ms_FIA_positive_assay.txt,14646,16704,5312,synthetic-isa-3samples-6assays
# a_blood_ms_FIA_negative_assay.txt,14486,16544,5312,synthetic-isa-3samples-6assays
# a_blood_ms_LC_positive_assay.txt,18561,21974,5312,synthetic-isa-3samples-6assays
# a_blood_ms_LC_negative_assay.txt,18561,21974,5312,synthetic-isa-3samples-6assays
# a_blood_ms_GC_positive_assay.txt,18561,21974,5312,synthetic-isa-3samples-6assays
# a_blood_ms_GC_negative_assay.txt,18561,21974,5312,synthetic-isa-3samples-6assays
# a_sweat_ms_FIA_positive_assay.txt,14886,16944,5312,synthetic-isa-3samples-6assays
# a_sweat_ms_FIA_negative_assay.txt,14566,16624,5312,synthetic-isa-3samples-6assays
# a_sweat_ms_LC_positive_assay.txt,14726,16784,5312,synthetic-isa-3samples-6assays
# a_sweat_ms_LC_negative_assay.txt,14566,16624,5312,synthetic-isa-3samples-6assays
# a_sweat_ms_GC_positive_assay.txt,14726,16784,5312,synthetic-isa-3samples-6assays
# a_sweat_ms_GC_negative_assay.txt,14726,16784,5312,synthetic-isa-3samples-6assays
# a_tears_ms_FIA_positive_assay.txt,14886,16944,5312,synthetic-isa-3samples-6assays
# a_tears_ms_FIA_negative_assay.txt,14566,16624,5312,synthetic-isa-3samples-6assays
# a_tears_ms_LC_positive_assay.txt,14726,16784,5312,synthetic-isa-3samples-6assays
# a_tears_ms_LC_negative_assay.txt,14566,16624,5312,synthetic-isa-3samples-6assays
# a_tears_ms_GC_positive_assay.txt,14726,16784,5312,synthetic-isa-3samples-6assays
# a_tears_ms_GC_negative_assay.txt,14726,16784,5312,synthetic-isa-3samples-6assays
# study.txt,9016,11115,2712,synthetic-isa-1sample-4assay
# a_blood_ms_LC_positive_assay.txt,18561,21974,5312,synthetic-isa-1sample-4assay
# a_blood_ms_LC_negative_assay.txt,18561,21974,5312,synthetic-isa-1sample-4assay
# a_blood_ms_GC_positive_assay.txt,18561,21974,5312,synthetic-isa-1sample-4assay
# a_blood_ms_GC_negative_assay.txt,18561,21974,5312,synthetic-isa-1sample-4assay
# study.txt,9016,11115,2712,synthetic-isa-1sample-2assay
# a_blood_ms_LC_negative_assay.txt,18561,21974,5312,synthetic-isa-1sample-2assay
# a_blood_ms_GC_negative_assay.txt,18561,21974,5312,synthetic-isa-1sample-2assay
# study.txt,17796,22135,5312,synthetic-isa-2samples-1assay
# a_blood_ms_GC_negative_assay.txt,18801,22214,5312,synthetic-isa-2samples-1assay
# a_sweat_ms_GC_negative_assay.txt,18841,22254,5312,synthetic-isa-2samples-1assay

# %%
df = pd.read_csv("synthetic-memory_footprint.csv")
# put the records by category to help with downstream processing
disk_sizes = []
obj_sizes = []
categories = []
study_ids = []

for _, row in df.iterrows():
    disk_sizes.append(row.disk_size)
    obj_sizes.append(row.df_size)
    study_ids.append(row.study_id)
    categories.append('DataFrame')
    disk_sizes.append(row.disk_size)
    obj_sizes.append(row.isa_size)
    study_ids.append(row.study_id)
    categories.append('ISA')
# What is this?? Messes up loop
#    if '_s' in row.study_id:
#        categories.append('CisaFrame')
#    elif '_a' in row.study_id:
#        categories.append('CisaFrame') 
     
df_by_cat = pd.DataFrame({
    'disk_size': disk_sizes,
    'size': obj_sizes,
    'log_size': np.log(obj_sizes),
    'category': categories,
    'study_id' : study_ids
})

df_sorted = df_by_cat.sort_values(by='category')
df_sorted.to_csv("synthetic-memory_by_category.csv", index=None)
df_sorted
# Out:
#     disk_size   size   log_size   category                        study_id
# 0        8976  11075   9.312446  DataFrame   synthetic-isa-1sample-6assays
# 34      18561  21974   9.997615  DataFrame  synthetic-isa-3samples-6assays
# 36      18561  21974   9.997615  DataFrame  synthetic-isa-3samples-6assays
# 38      18561  21974   9.997615  DataFrame  synthetic-isa-3samples-6assays
# 40      14886  16944   9.737669  DataFrame  synthetic-isa-3samples-6assays
# 84      18841  22254  10.010277  DataFrame   synthetic-isa-2samples-1assay
# 44      14726  16784   9.728181  DataFrame  synthetic-isa-3samples-6assays
# 46      14566  16624   9.718603  DataFrame  synthetic-isa-3samples-6assays
# 48      14726  16784   9.728181  DataFrame  synthetic-isa-3samples-6assays
# 50      14726  16784   9.728181  DataFrame  synthetic-isa-3samples-6assays
# 52      14886  16944   9.737669  DataFrame  synthetic-isa-3samples-6assays
# 54      14566  16624   9.718603  DataFrame  synthetic-isa-3samples-6assays
# 56      14726  16784   9.728181  DataFrame  synthetic-isa-3samples-6assays
# 58      14566  16624   9.718603  DataFrame  synthetic-isa-3samples-6assays
# 60      14726  16784   9.728181  DataFrame  synthetic-isa-3samples-6assays
# 62      14726  16784   9.728181  DataFrame  synthetic-isa-3samples-6assays
# 64       9016  11115   9.316051  DataFrame    synthetic-isa-1sample-4assay
# 66      18561  21974   9.997615  DataFrame    synthetic-isa-1sample-4assay
# 68      18561  21974   9.997615  DataFrame    synthetic-isa-1sample-4assay
# 70      18561  21974   9.997615  DataFrame    synthetic-isa-1sample-4assay
# 72      18561  21974   9.997615  DataFrame    synthetic-isa-1sample-4assay
# 74       9016  11115   9.316051  DataFrame    synthetic-isa-1sample-2assay
# 76      18561  21974   9.997615  DataFrame    synthetic-isa-1sample-2assay
# 78      18561  21974   9.997615  DataFrame    synthetic-isa-1sample-2assay
# 80      17796  22135  10.004915  DataFrame   synthetic-isa-2samples-1assay
# 82      18801  22214  10.008478  DataFrame   synthetic-isa-2samples-1assay
# 32      18561  21974   9.997615  DataFrame  synthetic-isa-3samples-6assays
# 30      14486  16544   9.713779  DataFrame  synthetic-isa-3samples-6assays
# 42      14566  16624   9.718603  DataFrame  synthetic-isa-3samples-6assays
# 20      18841  22254  10.010277  DataFrame   synthetic-isa-3samples-1assay
# ..        ...    ...        ...        ...                             ...
# 73      18561   5312   8.577724        ISA    synthetic-isa-1sample-4assay
# 5       14486   5312   8.577724        ISA   synthetic-isa-1sample-6assays
# 75       9016   2712   7.905442        ISA    synthetic-isa-1sample-2assay
# 77      18561   5312   8.577724        ISA    synthetic-isa-1sample-2assay
# 29      14646   5312   8.577724        ISA  synthetic-isa-3samples-6assays
# 57      14726   5312   8.577724        ISA  synthetic-isa-3samples-6assays
# 59      14566   5312   8.577724        ISA  synthetic-isa-3samples-6assays
# 27      26477   7912   8.976136        ISA  synthetic-isa-3samples-6assays
# 31      14486   5312   8.577724        ISA  synthetic-isa-3samples-6assays
# 33      18561   5312   8.577724        ISA  synthetic-isa-3samples-6assays
# 25      21770   5312   8.577724        ISA    synthetic-isa-1sample-1assay
# 35      18561   5312   8.577724        ISA  synthetic-isa-3samples-6assays
# 37      18561   5312   8.577724        ISA  synthetic-isa-3samples-6assays
# 23      11974   2712   7.905442        ISA    synthetic-isa-1sample-1assay
# 39      18561   5312   8.577724        ISA  synthetic-isa-3samples-6assays
# 41      14886   5312   8.577724        ISA  synthetic-isa-3samples-6assays
# 21      18841   5312   8.577724        ISA   synthetic-isa-3samples-1assay
# 43      14566   5312   8.577724        ISA  synthetic-isa-3samples-6assays
# 45      14726   5312   8.577724        ISA  synthetic-isa-3samples-6assays
# 19      18801   5312   8.577724        ISA   synthetic-isa-3samples-1assay
# 47      14566   5312   8.577724        ISA  synthetic-isa-3samples-6assays
# 49      14726   5312   8.577724        ISA  synthetic-isa-3samples-6assays
# 17      18841   5312   8.577724        ISA   synthetic-isa-3samples-1assay
# 51      14726   5312   8.577724        ISA  synthetic-isa-3samples-6assays
# 53      14886   5312   8.577724        ISA  synthetic-isa-3samples-6assays
# 15      26597   7912   8.976136        ISA   synthetic-isa-3samples-1assay
# 55      14566   5312   8.577724        ISA  synthetic-isa-3samples-6assays
# 13      18561   5312   8.577724        ISA   synthetic-isa-1sample-6assays
# 61      14726   5312   8.577724        ISA  synthetic-isa-3samples-6assays
# 85      18841   5312   8.577724        ISA   synthetic-isa-2samples-1assay
#
# [86 rows x 5 columns]
